# %% [markdown]
# # Disaster tweets
#
# The data used in this example is from Kaggle's Disaster Tweets: https://www.kaggle.com/competitions/nlp-getting-started/overview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
layers = tf.keras.layers

tweets = pd.read_csv('train.csv')
len(tweets[tweets.target == 0]) / len(tweets), len(tweets[tweets.target == 1]) / len(tweets)
# Out:
# (0.5703402075397347, 0.4296597924602653)

# %% [markdown]
# We see that the tweets are pretty balanced. We don't need to do anything here.

# %%
X = tweets.text.to_numpy()
y = tweets.target.to_numpy()

X.shape, y.shape
# Out:
# ((7613,), (7613,))

# %% [markdown]
# A lot of words are too common to matter, so-called stopwords. Typically, we get better results by removing the stopwords. Also removing the hash-tags, since I'm trying to solve it as a natural language problem.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

s_words = frozenset(stopwords.words('english'))

def clean(sentence):
  tokens = word_tokenize(sentence)
  tokens = [t.lower() for t in tokens if t not in s_words and not t.startswith('#')]
  return ' '.join(tokens)

X = np.array([clean(x) for x in X])
X[0:10]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ole\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Ole\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# array(['our deeds reason earthquake may allah forgive us',
#        'forest fire near la ronge sask . canada',
#        "all residents asked 'shelter place ' notified officers . no evacuation shelter place orders expected",
#        '13,000 people receive wildfires evacuation orders california',
#        'just got sent photo ruby alaska smoke wildfires pours school',
#        'rockyfire update = > california hwy . 20 closed directions due lake county fire - cafire wildfires',
#        'flood disaster heavy rain causes flash flooding streets manitou , colorado springs areas',
#        "i 'm top hill i see fire woods ...",
#        "there 's emergency evacuation happening building across street",
#        "i 'm afraid tornado coming area ..."], dtype='<U193')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=.8, random_state=504)
X_train, X_test = tf.convert_to_tensor(X_train, dtype=tf.string), tf.convert_to_tensor(X_test, dtype=tf.string)

# %% [markdown]
# # Building the model
#
# We'll need an embedding to get a semantic understanding of the words. We can either make a learnable Embedding layer or download a pre-trained one.
#
# Here I'm showing how to use the GloVe embedding. I ended up not using, though.
#
# __Note__: You have to download the embedding yourself. It's over 100MB.

# %%
GloVe = {}

with open('./glove.6B.50d.txt','r', encoding='UTF-8') as f:
    for line in f:
        values = line.split()
        word = values[0]
        vectors = np.asarray(values[1:],'float32')
        GloVe[word] = vectors
        
f.close()

embed_dim = len(GloVe['the'])

# %%
def create_embedding_matrix(vocabulary, dim):
  num_words = len(vocabulary)
  embedding_matrix = np.zeros((num_words, dim))

  hits, misses = 0, 0
  for i, word in enumerate(vocabulary):
    if word in GloVe:
      embedding_matrix[i] = GloVe[word]
      hits += 1
    else:
      misses +=1
  
  print(hits, misses)
  return embedding_matrix

# %% [markdown]
# The vectorization layer turns input strings into (arbitrary) vectors. It must be the first layer. We adapt it to the input text, so that it learns the words in the corpus. It's a good bet that the words in the corpus are common enough for future tweets.

# %%
vocab_size = 5000

vectorization = layers.TextVectorization(max_tokens=vocab_size, output_sequence_length=50)
vectorization.adapt(X)

# %% [markdown]
# The first layer after the vectorization is the embedding layer. The embedding layer turns the arbitrary vectors from the vectorization into something meaningful. How? It's learnable.
#
# Note the regularization on the Embedding layer. It has a lot of parameters and is at risk of overfitting (fitting to the training data instead of word meaning).
#
# The actual recurrent part of the network is quite small to combat overfitting.

# %%
# embedding_matrix = create_embedding_matrix(vectorization.get_vocabulary(), embed_dim)
# initializer = tf.keras.initializers.Constant(embedding_matrix)

ann = tf.keras.Sequential([
    layers.Input(shape=(1,), dtype='string'),
    vectorization,
    layers.Embedding(vocab_size, embed_dim, mask_zero=True, embeddings_regularizer=tf.keras.regularizers.L1(.005)),
    layers.SimpleRNN(6),
    layers.Dense(1, activation='sigmoid')
])
ann.summary()
# Out:
# 4569 431
# WARNING:tensorflow:From c:\Users\Ole\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\core.py:144: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# outputs (after conversion from ragged): Tensor("RaggedToTensor/RaggedTensorToTensor:0", shape=(None, 50), dtype=int64)
# c:\Users\Ole\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\layer.py:357: UserWarning: `build()` was called on layer 'text_vectorization', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ text_vectorization              │ (None, 50)                │          0 │
# │ (TextVectorization)             │                           │            │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ embedding (Embedding)           │ (None, 50, 50)            │    250,000 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 6)                 │        342 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense (Dense)                   │ (None, 1)                 │          7 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 250,349 (977.93 KB)
#  Trainable params: 250,349 (977.93 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
ann.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.002), metrics=['accuracy'])

es = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, start_from_epoch=25)
lr = tf.keras.callbacks.ReduceLROnPlateau(patience=10, factor=.5, min_lr=1e-5)

history = ann.fit(X_train, y_train, epochs = 100, validation_split=.2, callbacks=[es, lr])
# Out:
# Epoch 1/100
# outputs (after conversion from ragged): Tensor("sequential_1/text_vectorization_1/RaggedToTensor/RaggedTensorToTensor:0", shape=(None, 50), dtype=int64)
# outputs (after conversion from ragged): Tensor("sequential_1/text_vectorization_1/RaggedToTensor/RaggedTensorToTensor:0", shape=(None, 50), dtype=int64)
# 150/153 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5673 - loss: 8.1735outputs (after conversion from ragged): Tensor("sequential_1/text_vectorization_1/RaggedToTensor/RaggedTensorToTensor:0", shape=(None, 50), dtype=int64)
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.5683 - loss: 8.0438 - val_accuracy: 0.6474 - val_loss: 0.9670 - learning_rate: 0.0020
# Epoch 2/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6361 - loss: 0.9720 - val_accuracy: 0.6506 - val_loss: 0.9702 - learning_rate: 0.0020
# Epoch 3/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6563 - loss: 0.9706 - val_accuracy: 0.6538 - val_loss: 0.9695 - learning_rate: 0.0020
# Epoch 4/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6244 - loss: 0.9814 - val_accuracy: 0.6522 - val_loss: 0.9782 - learning_rate: 0.0020
# Epoch 5/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6393 - loss: 0.9831 - val_accuracy: 0.6579 - val_loss: 0.9841 - learning_rate: 0.0020
# Epoch 6/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6374 - loss: 0.9913 - val_accuracy: 0.6162 - val_loss: 1.0000 - learning_rate: 0.0020
# Epoch 7/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6553 - loss: 0.9883 - val_accuracy: 0.6362 - val_loss: 1.0066 - learning_rate: 0.0020
# Epoch 8/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6576 - loss: 0.9911 - val_accuracy: 0.6715 - val_loss: 1.0243 - learning_rate: 0.0020
# Epoch 9/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6772 - loss: 1.0411 - val_accuracy: 0.7292 - val_loss: 1.1197 - learning_rate: 0.0020
# Epoch 10/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7370 - loss: 1.1233 - val_accuracy: 0.7396 - val_loss: 1.1977 - learning_rate: 0.0020
# Epoch 11/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7756 - loss: 1.1449 - val_accuracy: 0.7636 - val_loss: 1.1518 - learning_rate: 0.0020
# Epoch 12/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8117 - loss: 0.9069 - val_accuracy: 0.7869 - val_loss: 0.8774 - learning_rate: 0.0010
# Epoch 13/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8283 - loss: 0.8194 - val_accuracy: 0.7829 - val_loss: 0.9021 - learning_rate: 0.0010
# Epoch 14/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8476 - loss: 0.7888 - val_accuracy: 0.7732 - val_loss: 0.9027 - learning_rate: 0.0010
# Epoch 15/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8548 - loss: 0.7719 - val_accuracy: 0.7925 - val_loss: 0.8840 - learning_rate: 0.0010
# Epoch 16/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8678 - loss: 0.7453 - val_accuracy: 0.7901 - val_loss: 0.8996 - learning_rate: 0.0010
# Epoch 17/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8648 - loss: 0.7595 - val_accuracy: 0.7756 - val_loss: 0.9237 - learning_rate: 0.0010
# Epoch 18/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8742 - loss: 0.7355 - val_accuracy: 0.7716 - val_loss: 0.9096 - learning_rate: 0.0010
# Epoch 19/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8798 - loss: 0.7105 - val_accuracy: 0.7740 - val_loss: 0.9355 - learning_rate: 0.0010
# Epoch 20/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8856 - loss: 0.7112 - val_accuracy: 0.7684 - val_loss: 0.9388 - learning_rate: 0.0010
# Epoch 21/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8914 - loss: 0.6974 - val_accuracy: 0.7668 - val_loss: 0.9501 - learning_rate: 0.0010
# Epoch 22/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8854 - loss: 0.7088 - val_accuracy: 0.7788 - val_loss: 0.9411 - learning_rate: 0.0010
# Epoch 23/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9043 - loss: 0.5839 - val_accuracy: 0.7748 - val_loss: 0.8208 - learning_rate: 5.0000e-04
# Epoch 24/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9218 - loss: 0.5077 - val_accuracy: 0.7748 - val_loss: 0.8218 - learning_rate: 5.0000e-04
# Epoch 25/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9144 - loss: 0.5206 - val_accuracy: 0.7780 - val_loss: 0.8333 - learning_rate: 5.0000e-04
# Epoch 26/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9186 - loss: 0.5005 - val_accuracy: 0.7788 - val_loss: 0.8266 - learning_rate: 5.0000e-04
# Epoch 27/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9140 - loss: 0.5182 - val_accuracy: 0.7548 - val_loss: 0.8663 - learning_rate: 5.0000e-04
# Epoch 28/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9107 - loss: 0.5292 - val_accuracy: 0.7676 - val_loss: 0.8832 - learning_rate: 5.0000e-04
# Epoch 29/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9192 - loss: 0.5096 - val_accuracy: 0.7644 - val_loss: 0.8799 - learning_rate: 5.0000e-04
# Epoch 30/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9170 - loss: 0.5128 - val_accuracy: 0.7628 - val_loss: 0.8851 - learning_rate: 5.0000e-04
# Epoch 31/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9268 - loss: 0.4920 - val_accuracy: 0.7524 - val_loss: 0.9121 - learning_rate: 5.0000e-04
# Epoch 32/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9258 - loss: 0.4849 - val_accuracy: 0.7708 - val_loss: 0.8703 - learning_rate: 5.0000e-04
# Epoch 33/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9224 - loss: 0.4904 - val_accuracy: 0.7652 - val_loss: 0.8982 - learning_rate: 5.0000e-04
# Epoch 34/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9368 - loss: 0.4241 - val_accuracy: 0.7556 - val_loss: 0.8458 - learning_rate: 2.5000e-04
# Epoch 35/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9431 - loss: 0.3818 - val_accuracy: 0.7484 - val_loss: 0.8617 - learning_rate: 2.5000e-04
# Epoch 36/100
# 153/153 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9455 - loss: 0.3709 - val_accuracy: 0.7508 - val_loss: 0.8651 - learning_rate: 2.5000e-04

# %% [markdown]
# # The result
#
# RNNs tend to find these plateaus where it reaches something close to equilibrium, then breaks out of it rapidly. You can see that in the graphs below.
#
# The result is less than optimal. Lots of overfitting happening.

# %%
figure = plt.figure(figsize=(20, 10))
ax = figure.add_subplot(1, 2, 1, title='Learning curves (loss)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.plot(history.history['loss'][2:], label = 'train')
ax.plot(history.history['val_loss'][2:], label = 'valid')
ax.legend()

ax = figure.add_subplot(1, 2, 2, title='Learning curves (accuracy)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.plot(history.history['accuracy'], label = 'train')
ax.plot(history.history['val_accuracy'], label = 'valid')
ax.legend()

plt.show()

# %%
ann.evaluate(X_train, y_train)
ann.evaluate(X_test, y_test)
# Out:
# 191/191 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9275 - loss: 0.4941
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7663 - loss: 0.8388
# [0.836371898651123, 0.7638432383537292]
